# %% [markdown]
# #### Extracting MFCC's for every file
#
# We will now extract an MFCC for each audio file in the dataset and store it in a Panda Dataframe along with it's classification label.

# %%
import librosa
def extract_features(file_name):
   
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        mfccsscaled = np.mean(mfccs.T,axis=0)
        
    except Exception as e:
        print("Error encountered while parsing file: ", file)
        return None 
     
    return mfccsscaled

# %%
# Load various imports 
import pandas as pd
import os
import librosa

# Set the path to the full UrbanSound dataset 
fulldatasetpath = '../dataset/UrbanSound8K/audio/'

metadata = pd.read_csv('../dataset/metadata/UrbanSound8K.csv')

features = []

# Iterate through each sound file and extract the features 
for index, row in metadata.iterrows():
    
    file_name = os.path.join(os.path.abspath(fulldatasetpath),'fold'+str(row["fold"])+'/',str(row["slice_file_name"]))
    
    class_label = row["class_name"]
    data = extract_features(file_name)
    
    features.append([data, class_label])

# Convert into a Panda dataframe 
featuresdf = pd.DataFrame(features, columns=['feature','class_label'])

print('Finished feature extraction from ', len(featuresdf), ' files')
# Out:
# Finished feature extraction from  49  files

# %%
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical

# Convert features and corresponding classification labels into numpy arrays
X = np.array(featuresdf.feature.tolist())
y = np.array(featuresdf.class_label.tolist())

# Encode the classification labels
le = LabelEncoder()
yy = to_categorical(le.fit_transform(y))
# Out:
# Using TensorFlow backend.

# %%
# split the dataset 
from sklearn.model_selection import train_test_split 

x_train, x_test, y_train, y_test = train_test_split(X, yy, test_size=0.2, random_state = 42)

# %%
### store the preprocessed data for use in the next notebook

# %store x_train 
# %store x_test 
# %store y_train 
# %store y_test 
# %store yy 
# %store le
# Out:
# Stored 'x_train' (ndarray)
# Stored 'x_test' (ndarray)
# Stored 'y_train' (ndarray)
# Stored 'y_test' (ndarray)
# Stored 'yy' (ndarray)
# Stored 'le' (LabelEncoder)

# %%
# retrieve the preprocessed data from previous notebook

# %store -r x_train 
# %store -r x_test 
# %store -r y_train 
# %store -r y_test 
# %store -r yy 
# %store -r le

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, MaxPooling2D
from keras.optimizers import Adam
from keras.utils import np_utils
from sklearn import metrics 

num_labels = yy.shape[1]
filter_size = 2

# Construct model 
model = Sequential()

model.add(Dense(256, input_shape=(40,)))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(num_labels))
model.add(Activation('softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=0)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 256)               10496
# _________________________________________________________________
# activation_1 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 1285
# _________________________________________________________________
# activation_3 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 77,573
# Trainable params: 77,573
# Non-trainable params: 0
# _________________________________________________________________
# Pre-training accuracy: 30.0000%

# %%
from keras.callbacks import ModelCheckpoint 
from datetime import datetime 

num_epochs = 100
num_batch_size = 32

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.basic_mlp.hdf5', 
                               verbose=1, save_best_only=True)
start = datetime.now()

model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(x_test, y_test), callbacks=[checkpointer], verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 39 samples, validate on 10 samples
# Epoch 1/100
# 39/39 [==============================] - 0s 4ms/step - loss: 59.3815 - accuracy: 0.1795 - val_loss: 12.9121 - val_accuracy: 0.3000
#
# Epoch 00001: val_loss improved from inf to 12.91209, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 2/100
# 39/39 [==============================] - 0s 499us/step - loss: 59.7880 - accuracy: 0.2051 - val_loss: 13.8285 - val_accuracy: 0.3000
#
# Epoch 00002: val_loss did not improve from 12.91209
# Epoch 3/100
# 39/39 [==============================] - 0s 381us/step - loss: 71.3824 - accuracy: 0.2051 - val_loss: 20.2391 - val_accuracy: 0.3000
#
# Epoch 00003: val_loss did not improve from 12.91209
# Epoch 4/100
# 39/39 [==============================] - 0s 593us/step - loss: 59.9508 - accuracy: 0.1795 - val_loss: 23.8543 - val_accuracy: 0.3000
#
# Epoch 00004: val_loss did not improve from 12.91209
# Epoch 5/100
# 39/39 [==============================] - 0s 428us/step - loss: 49.2047 - accuracy: 0.2051 - val_loss: 26.8128 - val_accuracy: 0.3000
#
# Epoch 00005: val_loss did not improve from 12.91209
# Epoch 6/100
# 39/39 [==============================] - 0s 544us/step - loss: 53.0530 - accuracy: 0.1538 - val_loss: 26.9975 - val_accuracy: 0.3000
#
# Epoch 00006: val_loss did not improve from 12.91209
# Epoch 7/100
# 39/39 [==============================] - 0s 383us/step - loss: 46.0922 - accuracy: 0.2051 - val_loss: 21.5832 - val_accuracy: 0.3000
#
# Epoch 00007: val_loss did not improve from 12.91209
# Epoch 8/100
# 39/39 [==============================] - 0s 747us/step - loss: 49.5513 - accuracy: 0.2564 - val_loss: 16.4859 - val_accuracy: 0.3000
#
# Epoch 00008: val_loss did not improve from 12.91209
# Epoch 9/100
# 39/39 [==============================] - 0s 699us/step - loss: 42.3751 - accuracy: 0.2308 - val_loss: 11.6512 - val_accuracy: 0.3000
#
# Epoch 00009: val_loss improved from 12.91209 to 11.65120, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 10/100
# 39/39 [==============================] - 0s 547us/step - loss: 49.3999 - accuracy: 0.1795 - val_loss: 8.4413 - val_accuracy: 0.3000
#
# Epoch 00010: val_loss improved from 11.65120 to 8.44131, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 11/100
# 39/39 [==============================] - 0s 848us/step - loss: 51.6409 - accuracy: 0.2051 - val_loss: 9.5222 - val_accuracy: 0.0000e+00
#
# Epoch 00011: val_loss did not improve from 8.44131
# Epoch 12/100
# 39/39 [==============================] - 0s 723us/step - loss: 32.0459 - accuracy: 0.2821 - val_loss: 11.7996 - val_accuracy: 0.0000e+00
#
# Epoch 00012: val_loss did not improve from 8.44131
# Epoch 13/100
# 39/39 [==============================] - 0s 992us/step - loss: 37.0216 - accuracy: 0.2051 - val_loss: 13.7132 - val_accuracy: 0.0000e+00
#
# Epoch 00013: val_loss did not improve from 8.44131
# Epoch 14/100
# 39/39 [==============================] - 0s 684us/step - loss: 32.4836 - accuracy: 0.2821 - val_loss: 16.5176 - val_accuracy: 0.3000
#
# Epoch 00014: val_loss did not improve from 8.44131
# Epoch 15/100
# 39/39 [==============================] - 0s 445us/step - loss: 31.1907 - accuracy: 0.3333 - val_loss: 19.1304 - val_accuracy: 0.3000
#
# Epoch 00015: val_loss did not improve from 8.44131
# Epoch 16/100
# 39/39 [==============================] - 0s 556us/step - loss: 35.2616 - accuracy: 0.1538 - val_loss: 20.0073 - val_accuracy: 0.3000
#
# Epoch 00016: val_loss did not improve from 8.44131
# Epoch 17/100
# 39/39 [==============================] - 0s 544us/step - loss: 31.6700 - accuracy: 0.2308 - val_loss: 18.9131 - val_accuracy: 0.3000
#
# Epoch 00017: val_loss did not improve from 8.44131
# Epoch 18/100
# 39/39 [==============================] - 0s 535us/step - loss: 42.6342 - accuracy: 0.1538 - val_loss: 15.6414 - val_accuracy: 0.3000
#
# Epoch 00018: val_loss did not improve from 8.44131
# Epoch 19/100
# 39/39 [==============================] - 0s 546us/step - loss: 44.5846 - accuracy: 0.1282 - val_loss: 11.6075 - val_accuracy: 0.3000
#
# Epoch 00019: val_loss did not improve from 8.44131
# Epoch 20/100
# 39/39 [==============================] - 0s 527us/step - loss: 32.2750 - accuracy: 0.1795 - val_loss: 7.6424 - val_accuracy: 0.3000
#
# Epoch 00020: val_loss improved from 8.44131 to 7.64242, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 21/100
# 39/39 [==============================] - 0s 569us/step - loss: 29.9979 - accuracy: 0.2051 - val_loss: 5.2216 - val_accuracy: 0.3000
#
# Epoch 00021: val_loss improved from 7.64242 to 5.22162, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch
 0.0000e+00
#
# Epoch 00038: val_loss did not improve from 1.79868
# Epoch 39/100
# 39/39 [==============================] - 0s 714us/step - loss: 16.4879 - accuracy: 0.2564 - val_loss: 6.8700 - val_accuracy: 0.0000e+00
#
# Epoch 00039: val_loss did not improve from 1.79868
# Epoch 40/100
# 39/39 [==============================] - 0s 549us/step - loss: 20.9566 - accuracy: 0.2564 - val_loss: 6.7120 - val_accuracy: 0.0000e+00
#
# Epoch 00040: val_loss did not improve from 1.79868
# Epoch 41/100
# 39/39 [==============================] - 0s 391us/step - loss: 21.6746 - accuracy: 0.2308 - val_loss: 5.8539 - val_accuracy: 0.0000e+00
#
# Epoch 00041: val_loss did not improve from 1.79868
# Epoch 42/100
# 39/39 [==============================] - 0s 660us/step - loss: 19.4303 - accuracy: 0.3333 - val_loss: 4.5322 - val_accuracy: 0.0000e+00
#
# Epoch 00042: val_loss did not improve from 1.79868
# Epoch 43/100
# 39/39 [==============================] - 0s 1ms/step - loss: 16.4145 - accuracy: 0.3077 - val_loss: 2.9953 - val_accuracy: 0.0000e+00
#
# Epoch 00043: val_loss did not improve from 1.79868
# Epoch 44/100
# 39/39 [==============================] - 0s 839us/step - loss: 19.9231 - accuracy: 0.2308 - val_loss: 2.2408 - val_accuracy: 0.4000
#
# Epoch 00044: val_loss did not improve from 1.79868
# Epoch 45/100
# 39/39 [==============================] - 0s 566us/step - loss: 15.0927 - accuracy: 0.2564 - val_loss: 1.9619 - val_accuracy: 0.4000
#
# Epoch 00045: val_loss did not improve from 1.79868
# Epoch 46/100
# 39/39 [==============================] - 0s 702us/step - loss: 18.2728 - accuracy: 0.0769 - val_loss: 1.9505 - val_accuracy: 0.3000
#
# Epoch 00046: val_loss did not improve from 1.79868
# Epoch 47/100
# 39/39 [==============================] - 0s 624us/step - loss: 13.6649 - accuracy: 0.2564 - val_loss: 1.8837 - val_accuracy: 0.3000
#
# Epoch 00047: val_loss did not improve from 1.79868
# Epoch 48/100
# 39/39 [==============================] - 0s 511us/step - loss: 12.9408 - accuracy: 0.3333 - val_loss: 1.7544 - val_accuracy: 0.3000
#
# Epoch 00048: val_loss improved from 1.79868 to 1.75437, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 49/100
# 39/39 [==============================] - 0s 857us/step - loss: 15.5524 - accuracy: 0.1282 - val_loss: 1.7732 - val_accuracy: 0.3000
#
# Epoch 00049: val_loss did not improve from 1.75437
# Epoch 50/100
# 39/39 [==============================] - 0s 1ms/step - loss: 12.8863 - accuracy: 0.3077 - val_loss: 1.9397 - val_accuracy: 0.2000
#
# Epoch 00050: val_loss did not improve from 1.75437
# Epoch 51/100
# 39/39 [==============================] - 0s 617us/step - loss: 14.7748 - accuracy: 0.2051 - val_loss: 2.2570 - val_accuracy: 0.0000e+00
#
# Epoch 00051: val_loss did not improve from 1.75437
# Epoch 52/100
# 39/39 [==============================] - 0s 508us/step - loss: 13.6182 - accuracy: 0.2564 - val_loss: 2.3583 - val_accuracy: 0.1000
#
# Epoch 00052: val_loss did not improve from 1.75437
# Epoch 53/100
# 39/39 [==============================] - 0s 525us/step - loss: 12.4000 - accuracy: 0.1795 - val_loss: 2.3380 - val_accuracy: 0.2000
#
# Epoch 00053: val_loss did not improve from 1.75437
# Epoch 54/100
# 39/39 [==============================] - 0s 582us/step - loss: 10.1084 - accuracy: 0.2308 - val_loss: 2.2560 - val_accuracy: 0.0000e+00
#
# Epoch 00054: val_loss did not improve from
#
# Epoch 00071: val_loss did not improve from 1.63328
# Epoch 72/100
# 39/39 [==============================] - 0s 460us/step - loss: 6.9082 - accuracy: 0.1795 - val_loss: 1.6556 - val_accuracy: 0.1000
#
# Epoch 00072: val_loss did not improve from 1.63328
# Epoch 73/100
# 39/39 [==============================] - 0s 442us/step - loss: 6.9102 - accuracy: 0.2308 - val_loss: 1.6422 - val_accuracy: 0.2000
#
# Epoch 00073: val_loss did not improve from 1.63328
# Epoch 74/100
# 39/39 [==============================] - 0s 339us/step - loss: 5.8269 - accuracy: 0.3077 - val_loss: 1.6252 - val_accuracy: 0.2000
#
# Epoch 00074: val_loss improved from 1.63328 to 1.62521, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 75/100
# 39/39 [==============================] - 0s 631us/step - loss: 6.6107 - accuracy: 0.1538 - val_loss: 1.6158 - val_accuracy: 0.2000
#
# Epoch 00075: val_loss improved from 1.62521 to 1.61580, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 76/100
# 39/39 [==============================] - 0s 910us/step - loss: 6.5033 - accuracy: 0.1282 - val_loss: 1.6137 - val_accuracy: 0.4000
#
# Epoch 00076: val_loss improved from 1.61580 to 1.61369, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 77/100
# 39/39 [==============================] - 0s 966us/step - loss: 4.7399 - accuracy: 0.2821 - val_loss: 1.6132 - val_accuracy: 0.4000
#
# Epoch 00077: val_loss improved from 1.61369 to 1.61324, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 78/100
# 39/39 [==============================] - 0s 804us/step - loss: 7.2644 - accuracy: 0.1538 - val_loss: 1.6125 - val_accuracy: 0.4000
#
# Epoch 00078: val_loss improved from 1.61324 to 1.61250, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 79/100
# 39/39 [==============================] - 0s 776us/step - loss: 4.4203 - accuracy: 0.1795 - val_loss: 1.6098 - val_accuracy: 0.4000
#
# Epoch 00079: val_loss improved from 1.61250 to 1.60979, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 80/100
# 39/39 [==============================] - 0s 383us/step - loss: 4.9377 - accuracy: 0.3590 - val_loss: 1.6107 - val_accuracy: 0.1000
#
# Epoch 00080: val_loss did not improve from 1.60979
# Epoch 81/100
# 39/39 [==============================] - 0s 541us/step - loss: 5.1960 - accuracy: 0.1795 - val_loss: 1.6108 - val_accuracy: 0.1000
#
# Epoch 00081: val_loss did not improve from 1.60979
# Epoch 82/100
# 39/39 [==============================] - 0s 761us/step - loss: 4.8625 - accuracy: 0.2308 - val_loss: 1.6069 - val_accuracy: 0.1000
#
# Epoch 00082: val_loss improved from 1.60979 to 1.60695, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 83/100
# 39/39 [==============================] - 0s 1ms/step - loss: 4.5884 - accuracy: 0.2308 - val_loss: 1.6045 - val_accuracy: 0.1000
#
# Epoch 00083: val_loss improved from 1.60695 to 1.60452, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 84/100
# 39/39 [==============================] - 0s 393us/step - loss: 3.7697 - accuracy: 0.2821 - val_loss: 1.6093 - val_accuracy: 0.0000e+00
#
# Epoch 00084: val_loss did not improve from 1.60452
# Epoch 85/100
# 39/39 [==============================] - 0s 560us/step - loss: 4.0095 - accuracy: 0.1795 - val_loss: 1.6096 - val_accuracy: 0.0000e+00
#
# Epoch 00085: val_loss did not improve from 1.60452
# Epoch 86/100
# 39/39 [==============================] - 0s 763us/step - loss: 4.3342 - accuracy: 0.2821 - val_loss: 1.6098 - val_accuracy: 0.0000e+00
#
# Epoch 00086: val_loss did not improve from 1.60452
# Epoch 87/100
# 39/39 [==============================] - 0s 1ms/step - loss: 4.0025 - accuracy: 0.1795 - val_loss: 1.6100 - val_accuracy: 0.0000e+00
#
# Epoch 00087: val_loss did not improve from 1.60452
# Epoch 88/100
# 39/39 [==============================] - 0s 791us/step - loss: 4.4238 - accuracy: 0.2308 - val_loss: 1.6100 - val_accuracy: 0.0000e+00
#
# Epoch 00088: val_loss did not improve from 1.60452
# Epoch 89/100
# 39/39 [==============================] - 0s 497us/step - loss: 3.9770 - accuracy: 0.2308 - val_loss: 1.6101 - val_accuracy: 0.0000e+00
#
# Epoch 00089: val_loss did not improve from 1.60452
# Epoch 90/100
# 39/39 [==============================] - 0s 511us/step - loss: 3.7646 - accuracy: 0.2051 - val_loss: 1.6100 - val_accuracy: 0.0000e+00
#
# Epoch 00090: val_loss did not improve from 1.60452
# Epoch 91/100
# 39/39 [==============================] - 0s 755us/step - loss: 4.2907 - accuracy: 0.2308 - val_loss: 1.6100 - val_accuracy: 0.0000e+00
#
# Epoch 00091: val_loss did not improve from 1.60452
# Epoch 92/100
# 39/39 [==============================] - 0s 825us/step - loss: 3.8232 - accuracy: 0.2308 - val_loss: 1.6099 - val_accuracy: 0.0000e+00
#
# Epoch 00092: val_loss did not improve from 1.60452
# Epoch 93/100
# 39/39 [==============================] - ETA: 0s - loss: 3.0782 - accuracy: 0.31 - 0s 966us/step - loss: 3.0716 - accuracy: 0.3077 - val_loss: 1.6098 - val_accuracy: 0.0000e+00
#
# Epoch 00093: val_loss did not improve from 1.60452
# Epoch 94/100
# 39/39 [==============================] - 0s 711us/step - loss: 4.1316 - accuracy: 0.1795 - val_loss: 1.6098 - val_accuracy: 0.0000e+00
#
# Epoch 00094: val_loss did not improve from 1.60452
# Epoch 95/100
# 39/39 [==============================] - 0s 572us/step - loss: 3.2113 - accuracy: 0.2564 - val_loss: 1.6098 - val_accuracy: 0.0000e+00
#
# Epoch 00095: val_loss did not improve from 1.60452
# Epoch 96/100
# 39/39 [==============================] - 0s 940us/step - loss: 4.0452 - accuracy: 0.2051 - val_loss: 1.6099 - val_accuracy: 0.0000e+00
#
# Epoch 00096: val_loss did not improve from 1.60452
# Epoch 97/100
# 39/39 [==============================] - 0s 628us/step - loss: 4.1914 - accuracy: 0.2051 - val_loss: 1.6099 - val_accuracy: 0.0000e+00
#
# Epoch 00097: val_loss did not improve from 1.60452
# Epoch 98/100
# 39/39 [==============================] - 0s 618us/step - loss: 3.3685 - accuracy: 0.2051 - val_loss: 1.6098 - val_accuracy: 0.0000e+00
#
# Epoch 00098: val_loss did not improve from 1.60452
# Epoch 99/100
# 39/39 [==============================] - 0s 921us/step - loss: 3.4276 - accuracy: 0.1795 - val_loss: 1.6098 - val_accuracy: 0.0000e+00
#
# Epoch 00099: val_loss did not improve from 1.60452
# Epoch 100/100
# 39/39 [==============================] - 0s 906us/step - loss: 2.4980 - accuracy: 0.2308 - val_loss: 1.6098 - val_accuracy: 0.0000e+00
#
# Epoch 00100: val_loss did not improve from 1.60452
# Training completed in time:  0:00:06.359233

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  0.28205129504203796
# Testing Accuracy:  0.0

# %%
import librosa 
import numpy as np 

def extract_feature(file_name):
   
    try:
        audio_data, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
        mfccs = librosa.feature.mfcc(y=audio_data, sr=sample_rate, n_mfcc=40)
        mfccsscaled = np.mean(mfccs.T,axis=0)
        
    except Exception as e:
        print("Error encountered while parsing file: ", file)
        return None, None

    return np.array([mfccsscaled])

# %%
def print_prediction(file_name):
    prediction_feature = extract_feature(file_name) 

    predicted_vector = model.predict_classes(prediction_feature)
    predicted_class = le.inverse_transform(predicted_vector) 
    print("The predicted class is:", predicted_class[0], '\n') 

    predicted_proba_vector = model.predict_proba(prediction_feature) 
    predicted_proba = predicted_proba_vector[0]
    for i in range(len(predicted_proba)): 
        category = le.inverse_transform(np.array([i]))
        print(category[0], "\t\t : ", format(predicted_proba[i], '.32f') )

# %%
# test

filename = '../dataset/audio/fb41.wav' 
print_prediction(filename)
# Out:
# The predicted class is: tap
#
# double_tap 		 :  0.19715674221515655517578125000000
# long_tap 		 :  0.19872373342514038085937500000000
# swipe 		 :  0.20130838453769683837890625000000
# tap 		 :  0.20246244966983795166015625000000
# zoom 		 :  0.20034867525100708007812500000000
